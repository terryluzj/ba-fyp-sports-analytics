# %%
import pandas as pd
import sqlite3

def select_return_table(table_name):
    # Select from all records and convert to pandas dataframe
    data = curs.execute('SELECT * FROM %s' % table_name).fetchall()
    column = [element[1] for element in curs.execute('PRAGMA table_info(%s)' % table_name).fetchall()]
    return pd.DataFrame(data, columns=column)

def get_missing_value_perc(df, cond=lambda x: x == 'null'):
    # Check missing value and output percentage
    df_sum = df.applymap(cond).sum()
    df_percentage = df.applymap(cond).sum() / df.applymap(lambda data: data == 'null').count()
    df_percentage = df_percentage.apply(lambda x: "{0:.2f}%".format(x * 100))
    return pd.concat([df_sum, df_percentage], axis=1, keys=["Missing Value", "Missing Value (%)"])

# %% [markdown]
# ## I. Database Connection

# %%
# Establish database connection and check table name
conn = sqlite3.connect('temp/race.db')
curs = conn.cursor()
table_name = curs.execute('SELECT name FROM sqlite_master WHERE type="table"').fetchall()
print(table_name)
# Out:
# [('race_record',), ('horse_record',), ('individual_record',), ('trainer_profile',), ('jockey_profile',)]

# %%
# Read from record data
record_dict = {name[0]: select_return_table(name[0]) for name in table_name}
race_df = record_dict['race_record']
horse_df = record_dict['horse_record']
individual_df = record_dict['individual_record']
trainer_df = record_dict['trainer_profile']
jockey_df = record_dict['jockey_profile']

# %% [markdown]
# ## II. Integrity Check

# %% [markdown]
# ### i. Race Record

# %%
# Snapshot of tha race_record dataframe
print(race_df.shape)
race_df.describe().T
# Out:
# (287681, 27)
#                      count unique              top    freq
# run_date            287681    681       2002-04-21     547
# place               287681     10               中山   41958
# race                287681     12               3R   26656
# title               287681   1642            3歳未勝利   67621
# type                287681      3                ダ  140215
# track               287681      4                右  189136
# distance            287681     67            1200m   68470
# weather             287681      6                晴  170843
# condition           287681      4                良  225379
# time                287681     85            12:50    8336
# finishing_position  287681     40                1   20707
# bracket             287681      8                8   42044
# horse_number        287681     18                2   20684
# horse               287681  32652        ハートランドヒリュ     100
# sex_age             287681     33               牡3   67010
# jockey_weight       287681     29               55   65242
# jockey              287681    597             中舘英二    5110
# run_time            287681   2813              ---    1291
# margin              287681   1092               クビ   47051
# corner_position     287681  11716              2-2   10937
# run_time_last_600   287681   1769             37.0    5160
# win_odds            287681   6576             null    1291
# win_fav             287681    587                1   20589
# horse_weight        287681   4158             null    2720
# trainer             287681    896             null    2720
# breeder             287681   3028  サラブレッドクラブ・ラフィアン    6743
# prize               287681   2569                -  181438

# %%
# Ensure that (almost) all races on the same day at the same place have a count of 12
race_count = curs.execute('SELECT DISTINCT run_date, place, race from race_record').fetchall()
race_count_df = pd.DataFrame(race_count, columns=['run_date', 'place', 'race'])
race_count_df.groupby(['run_date', 'place']).count().sample(n=10)
# Out:
#                   race
# run_date   place
# 2005-12-10 中山        6
# 2000-07-15 小倉       12
# 2001-04-07 中山       12
# 2005-08-07 新潟       12
# 2005-04-03 中山       12
# 2001-10-13 東京       12
# 2001-07-21 小倉       12
# 2000-03-19 阪神       12
# 2006-08-13 新潟        6
# 2002-07-27 小倉       12

# %% [markdown]
# ### ii. Horse Record

# %%
# Check the data columns
horse_df.sample(n=3)
# Out:
#       horse_name date_of_birth     trainer owner breeder place_of_birth  \
# 1457   マイネルシェーバー     1997年3月1日  田口輝彦  (笠松)  足立達昭    飛渡牧場            新冠町
# 14419   シンボリスキャン    1999年4月18日   斎藤宏  (美浦)  高橋一郎  シンボリ牧場            門別町
# 30147     グラインダー     2003年3月4日  菅原欣也  (栃木)  戸崎利彦    藤原牧場            静内町
#
#       transaction_price              prize_obtained            race_record  \
# 1457                  -  1,250万円 (中央) /1,671万円 (地方)     77戦9勝 [ 9-9-6-53 ]
# 14419                 -      510万円 (中央) /854万円 (地方)  66戦18勝 [ 18-16-7-25 ]
# 30147                 -       870万円 (中央) /18万円 (地方)     25戦2勝 [ 2-0-1-22 ]
#
#       highlight_race            relatives          parents status gender  \
# 1457   02'報知中津特別(OP)  ハワイアンエルフ 、 イシノハワイアン  リンドシェーバー キクカエルフ             セ
# 14419       02'3歳未出走      シンボリプレオ 、 マツニシキ    スキャン ビューティゲラン     抹消      牡
# 30147    08'3歳上500万下      カサロス 、 ディスパージョン   ラムタラ ダイヤモンドロッチ             牡
#
#       breed offer_info
# 1457     鹿毛       null
# 14419   黒鹿毛       null
# 30147    栗毛       null

# %%
# Snapshot of tha race_record dataframe
print(horse_df.shape)
horse_df.describe().T
# Out:
# (32648, 16)
#                    count unique                  top   freq
# horse_name         32648  32648             セレスエンブレム      1
# date_of_birth      32648   1905            2002年4月3日     72
# trainer            32648   1447           藤沢和雄  (美浦)    147
# owner              32648   4677            サンデーレーシング    493
# breeder            32648   3017             ノーザンファーム   1175
# place_of_birth     32648     92                  浦河町   6205
# transaction_price  32648   2771                    -  27523
# prize_obtained     32648  15805                  0万円   5213
# race_record        32648  12211     2戦0勝 [ 0-0-0-2 ]   1167
# highlight_race     32648   6651                       10355
# relatives          32648  21853                        1303
# parents            32648  30361  サクラバクシンオー クリスタルトロフィ      6
# status             32648      3                   抹消  20995
# gender             32648      8                    牡  17358
# breed              32648      8                   鹿毛  16417
# offer_info         32648    151                 null  32122

# %% [markdown]
# ### iii. Individual Record

# %%
# Check the data columns
individual_df.sample(n=3)
# Out:
#       individual_type    name  year rank first second third out races_major  \
# 46621              馬主      名駿  1998  454     1      2     2  17           0
# 43904             生産者    佐藤信広  2010  574     0      2     1  26           0
# 4016              生産者  斉藤スタッド  2002  464     2      3     6  27           1
#
#       wins_major         ...          wins_flat races_grass wins_grass  \
# 46621          0         ...                  1          18          1
# 43904          0         ...                  0          11          0
# 4016           0         ...                  2          22          1
#
#       races_dirt wins_dirt wins_percent wins_percent_2nd wins_percent_3rd  \
# 46621          4         0         .045             .136             .227
# 43904         18         0         .000             .069             .103
# 4016          17         1         .051             .128             .282
#
#       prize_obtained representative_horse
# 46621        2,919.7              グランドウィン
# 43904        2,014.6            アドバンスヘイロー
# 4016         3,189.1             アマートベンハー
#
# [3 rows x 23 columns]

# %%
# Snapshot of tha race_record dataframe
print(individual_df.shape)
individual_df.describe().T
# Out:
# (84936, 23)
#                       count unique   top   freq
# individual_type       84936      4    馬主  35940
# name                  84936   7384  村田牧場     33
# year                  84936     33  2000   4159
# rank                  84936   1499  1313    736
# first                 84936    190     0  34471
# second                84936    164     0  36226
# third                 84936    152     0  34665
# out                   84936    744     1   5995
# races_major           84936    124     0  56020
# wins_major            84936     29     0  78458
# races_special         84936    341     0  23865
# wins_special          84936     77     0  60540
# races_flat            84936    710     1   5247
# wins_flat             84936    143     0  37956
# races_grass           84936    589     0   9710
# wins_grass            84936    124     0  50324
# races_dirt            84936    513     0  10048
# wins_dirt             84936    100     0  47091
# wins_percent          84936    310  .000  34471
# wins_percent_2nd      84936    474  .000  26771
# wins_percent_3rd      84936    575  .000  21991
# prize_obtained        84936  34858   0.0  15257
# representative_horse  84936  39247  null     64

# %% [markdown]
# ### iv. Trainer Profile

# %%
# Check the data columns
trainer_df.sample(n=3)
# Out:
#     trainer_name date_of_birth place_of_birth first_run_date first_run_horse  \
# 93       [東]高松邦男    1948/02/26            千葉県     1979/03/03         キリープリンス
# 568       [地]工藤勉    1959/08/29           null           null            null
# 12       [東]佐藤吉勝    1957/11/04            福島県     1999/03/07         ドミニカシチー
#
#     first_win_date first_win_horse
# 93      1979/05/06       キョウエイジョージ
# 568           null            null
# 12      1999/04/17         ニシノボルドー

# %%
# Snapshot of tha race_record dataframe
print(trainer_df.shape)
trainer_df.describe().T
# Out:
# (784, 7)
#                 count unique         top freq
# trainer_name      784    784      [地]斉藤尭    1
# date_of_birth     784    756  1956/10/09    2
# place_of_birth    784     36        null  563
# first_run_date    784    154        null  565
# first_run_horse   784    220        null  565
# first_win_date    784    208        null  565
# first_win_horse   784    220        null  565

# %% [markdown]
# ### v. Jockey Profile

# %%
# Check the data columns
jockey_df.sample(n=3)
# Out:
#     jockey_name date_of_birth place_of_birth blood_type height weight  \
# 578        納谷和玖    1973/11/22           null       null   null   null
# 213        寺島祐治    1968/03/12           null       null   null   null
# 326        吉田順治    1968/01/12           null       null   null   null
#
#     first_flat_run_date first_flat_run_horse first_flat_win_date  \
# 578          2006/04/16             ワイエスハッスル                null
# 213          1987/03/07              クボノブレーブ          1987/04/19
# 326          1997/08/16              ワンダーアモン                null
#
#     first_flat_win_horse first_obs_run_date first_obs_run_horse  \
# 578                 null               null                null
# 213             シービースマイル               null                null
# 326                 null               null                null
#
#     first_obs_win_date first_obs_win_horse
# 578               null                null
# 213               null                null
# 326               null                null

# %%
# Snapshot of tha race_record dataframe
print(jockey_df.shape)
jockey_df.describe().T
# Out:
# (593, 14)
#                      count unique         top freq
# jockey_name            593    593         田辺弘    1
# date_of_birth          593    580  1977/03/02    2
# place_of_birth         593     36        null  408
# blood_type             593      5        null  410
# height                 593     23        null  408
# weight                 593     16        null  408
# first_flat_run_date    593    316        null   29
# first_flat_run_horse   593    557        null   29
# first_flat_win_date    593    318        null  244
# first_flat_win_horse   593    348        null  244
# first_obs_run_date     593    141        null  438
# first_obs_run_horse    593    152        null  441
# first_obs_win_date     593     94        null  498
# first_obs_win_horse    593    100        null  494

# %% [markdown]
# ## III. Preprocessing

# %% [markdown]
# ### i. Missing Value

# %%
# Check missing value
get_missing_value_perc(race_df)
# Out:
#                     Missing Value Missing Value (%)
# run_date                        0             0.00%
# place                           0             0.00%
# race                            0             0.00%
# title                           0             0.00%
# type                            0             0.00%
# track                           0             0.00%
# distance                        0             0.00%
# weather                         0             0.00%
# condition                       0             0.00%
# time                            0             0.00%
# finishing_position              0             0.00%
# bracket                         0             0.00%
# horse_number                    0             0.00%
# horse                           0             0.00%
# sex_age                         0             0.00%
# jockey_weight                   0             0.00%
# jockey                          0             0.00%
# run_time                        0             0.00%
# margin                          0             0.00%
# corner_position                 0             0.00%
# run_time_last_600               0             0.00%
# win_odds                     1291             0.45%
# win_fav                      1847             0.64%
# horse_weight                 2720             0.95%
# trainer                      2720             0.95%
# breeder                      2778             0.97%
# prize                        2793             0.97%

# %%
# Check missing value
get_missing_value_perc(horse_df)
# Out:
#                    Missing Value Missing Value (%)
# horse_name                     0             0.00%
# date_of_birth                  0             0.00%
# trainer                        0             0.00%
# owner                          0             0.00%
# breeder                        0             0.00%
# place_of_birth                 0             0.00%
# transaction_price              0             0.00%
# prize_obtained                 0             0.00%
# race_record                    0             0.00%
# highlight_race                 0             0.00%
# relatives                      0             0.00%
# parents                        0             0.00%
# status                         0             0.00%
# gender                         0             0.00%
# breed                          0             0.00%
# offer_info                 32122            98.39%

# %%
# Check missing value
get_missing_value_perc(individual_df)
# Out:
#                       Missing Value Missing Value (%)
# individual_type                   0             0.00%
# name                              0             0.00%
# year                              0             0.00%
# rank                              0             0.00%
# first                            63             0.07%
# second                           63             0.07%
# third                            63             0.07%
# out                              63             0.07%
# races_major                      63             0.07%
# wins_major                       63             0.07%
# races_special                    63             0.07%
# wins_special                     63             0.07%
# races_flat                       63             0.07%
# wins_flat                        63             0.07%
# races_grass                      63             0.07%
# wins_grass                       63             0.07%
# races_dirt                       63             0.07%
# wins_dirt                        63             0.07%
# wins_percent                     63             0.07%
# wins_percent_2nd                 63             0.07%
# wins_percent_3rd                 63             0.07%
# prize_obtained                   63             0.07%
# representative_horse             64             0.08%

# %%
# Check missing value
get_missing_value_perc(trainer_df)
# Out:
#                  Missing Value Missing Value (%)
# trainer_name                 0             0.00%
# date_of_birth                0             0.00%
# place_of_birth             563            71.81%
# first_run_date             565            72.07%
# first_run_horse            565            72.07%
# first_win_date             565            72.07%
# first_win_horse            565            72.07%

# %%
# Check missing value
get_missing_value_perc(jockey_df)
# Out:
#                       Missing Value Missing Value (%)
# jockey_name                       0             0.00%
# date_of_birth                     0             0.00%
# place_of_birth                  408            68.80%
# blood_type                      410            69.14%
# height                          408            68.80%
# weight                          408            68.80%
# first_flat_run_date              29             4.89%
# first_flat_run_horse             29             4.89%
# first_flat_win_date             244            41.15%
# first_flat_win_horse            244            41.15%
# first_obs_run_date              438            73.86%
# first_obs_run_horse             441            74.37%
# first_obs_win_date              498            83.98%
# first_obs_win_horse             494            83.31%
